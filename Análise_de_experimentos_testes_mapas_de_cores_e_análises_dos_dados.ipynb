# %% [markdown]
# <a href="https://colab.research.google.com/github/JonasSouza871/Estatistica_python/blob/main/An%C3%A1lise_de_experimentos_testes_mapas_de_cores_e_an%C3%A1lises_dos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introdução à experimentação
#
# ----------------

# %% [markdown]
# ## 1.1. O caso de estudo
#
# ------------

# %% [markdown]
# - Empresa de vendas de cupcakes

# %% [markdown]
# - Você contrata o serviço dela e toda a sexta feira ela entrega uma quantidade x de cupcakes para alguem.

# %% [markdown]
# - como a quantidade de farinha e chocolate afetam o número de cupcakes produzidos?

# %% [markdown]
# - Ela quer entender melhor a receita dela.

# %% [markdown]
# - **Qual o papel da farinha e do chocolate na receita?**

# %% [markdown]
# - Representativo da realidade de trabalho
# - Conhecimento quantitativo

# %% [markdown]
# ### **Experimento**

# %% [markdown]
# -  Mexer na quantidade de farinha e chocolocate na receita e ir vendo o numero de cupcakes produzidos

# %% [markdown]
# ## 1.2. Planejamento do experimento
#
# -------------

# %% [markdown]
# - ela irá varia a quantidade de farinhas e chocolates e irá obtendo diferente porçoes com diferentes quantidade para análise.

# %% [markdown]
# - Ensaio feito:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
