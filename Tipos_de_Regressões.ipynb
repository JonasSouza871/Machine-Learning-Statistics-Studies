# %% [markdown]
# <a href="https://colab.research.google.com/github/JonasSouza871/Machine-Learning-Statistics-Studies/blob/main/Tipos_de_Regress%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Modelo Regressão Linear
#
# ------------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Relação linear entre variáveis: Assume que a mudança em Y é proporcional à mudança em X, criando uma linha reta quando plotada em um gráfico
# - Minimização de erros por mínimos quadrados: Encontra a melhor reta ajustando os coeficientes para minimizar a soma dos quadrados das distâncias verticais entre os pontos observados e a linha predita

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Pré processamento de dados:

# %%
dados = pd.read_csv('Dataset_temperatura_umidade.csv') #dados coletados atraves do dataseet no kaggle para temperatura e umidade
#link: https://www.kaggle.com/datasets/jonassouza872/temperature-vitria-da-conquista-08-25-to-08-29/code
#feito pelo proprio autor
dados
# Out:
#                  Timestamp  Temp_AHT20_C  Umid_AHT20_pct
# 0      2025-08-25 22:11:31         22.85           69.97
# 1      2025-08-25 22:11:37         22.82           69.05
# 2      2025-08-25 22:11:43         22.82           68.84
# 3      2025-08-25 22:11:49         22.85           69.00
# 4      2025-08-25 22:11:55         22.83           68.89
# ...                    ...           ...             ...
# 51100  2025-08-29 11:46:43         24.01           58.70
# 51101  2025-08-29 11:46:49         24.00           58.69
# 51102  2025-08-29 11:46:55         23.93           56.39
# 51103  2025-08-29 11:47:01         23.94           56.71
# 51104  2025-08-29 11:47:07         23.96           56.18
#
# [51105 rows x 3 columns]

# %%
df = pd.DataFrame(dados) #Transforma em dataframe
df
# Out:
#                  Timestamp  Temp_AHT20_C  Umid_AHT20_pct
# 0      2025-08-25 22:11:31         22.85           69.97
# 1      2025-08-25 22:11:37         22.82           69.05
# 2      2025-08-25 22:11:43         22.82           68.84
# 3      2025-08-25 22:11:49         22.85           69.00
# 4      2025-08-25 22:11:55         22.83           68.89
# ...                    ...           ...             ...
# 51100  2025-08-29 11:46:43         24.01           58.70
# 51101  2025-08-29 11:46:49         24.00           58.69
# 51102  2025-08-29 11:46:55         23.93           56.39
# 51103  2025-08-29 11:47:01         23.94           56.71
# 51104  2025-08-29 11:47:07         23.96           56.18
#
# [51105 rows x 3 columns]

# %%
df['Temp_AHT20_C'].describe()
# Out:
# count    51105.000000
# mean        20.034183
# std          2.816140
# min         15.080000
# 25%         17.520000
# 50%         19.280000
# 75%         22.510000
# max         25.940000
# Name: Temp_AHT20_C, dtype: float64

# %%
plt.scatter(df['Temp_AHT20_C'], df['Umid_AHT20_pct']) #plota temperatura e umidade
plt.title('Umidade x Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Umidade')
plt.show()

# %% [markdown]
# -  como são varios dados de temperatura >50000 por isso que fica estranho os dados.

# %%
import statsmodels.formula.api as smf #biblioteca para usar os modelos de regressao
import statsmodels.stats.api as sms

regressao = smf.ols(formula = 'Umid_AHT20_pct ~ Temp_AHT20_C', data = df).fit()
#variavel Umidade sendo Y e temperatura sendo x
# y = ax
# mostrando que a umidade é dependente da temperatura
print(regressao.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Umid_AHT20_pct   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                 2.667e+05
# Date:                Sat, 27 Sep 2025   Prob (F-statistic):               0.00
# Time:                        19:08:26   Log-Likelihood:            -1.4956e+05
# No. Observations:               51105   AIC:                         2.991e+05
# Df Residuals:                   51103   BIC:                         2.991e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      143.3316      0.144    998.691      0.000     143.050     143.613
# Temp_AHT20_C    -3.6637      0.007   -516.450      0.000      -3.678      -3.650
# ==============================================================================
# Omnibus:                     1035.425   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              983.876
# Skew:                          -0.302   Prob(JB):                    2.26e-214
# Kurtosis:                       2.690   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
regressao.params
# Out:
# Intercept       143.331585
# Temp_AHT20_C     -3.663688
# dtype: float64

# %% [markdown]
# - Interceptor considerando que em 0 graus a umidade esperada é de 143%, o que nao faz sentido logico visto que o maximo é 100%. Mostrando assim que o mdoelo so funciona na faixa esperada.

# %% [markdown]
# f(x) = ax +b

# %% [markdown]
# f(x) = -3.66*x +143.33

# %%
x = 18 # temperatura de 18 graus.
y = -3.66*x +143.33
print(y) # 77% de umidade previsto
# Out:
# 77.45000000000002

# %% [markdown]
# - tambem temos o valor de r^2 de 0.839 temos que a temperatura explica 83,9% dos dados de umidade

# %%
plt.scatter(df['Temp_AHT20_C'], df['Umid_AHT20_pct'], s = 50, color= 'blue', alpha = 0.6)
plt.plot(df['Temp_AHT20_C'], regressao.fittedvalues, color = 'red')
plt.title('Umidade x Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Umidade')
plt.show()

# %% [markdown]
# - por mais que o modelo tenha representado bom valores de r^2 ainda sim ficou mio estranho o fato de se a temperatura der igual a 0 a umidade ser 143% o que não é possivel.

# %% [markdown]
# - As melhores predições do modelo será na faixa que foi exposto (entre 16°c e 26°c)

# %% [markdown]
# # 2. Regressão Polinomial
# ----------------

# %% [markdown]
# ## 2.1.  Regressão Polinomial de 2° Grau
#
# ---------------------

# %% [markdown]
# - Captura relações curvilíneas: Modela padrões em forma de U ou U invertido, útil quando o efeito de X sobre Y acelera ou desacelera conforme X aumenta
# - Termo quadrático adicional: Inclui X² na equação, permitindo que o modelo identifique pontos de máximo ou mínimo (vértice da parábola) nos dados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# f(x) = b2x^2 + b1*x + b0

# %%
coeficientes = np.polyfit(df['Temp_AHT20_C'], df['Umid_AHT20_pct'], 1)  # treina funções polinomias com base no ultimos parametro
# veja que eu defini 1 no final, o que indica que o modleo será treinado como  regressão linear
modelo_linear = np.poly1d(coeficientes) #calcula os coeficientes do modelo
modelo_linear#os valores batem com o que foi achado acima
# Out:
# poly1d([ -3.66368759, 143.33158509])

# %% [markdown]
# - Aplicando agora a regressão quadrático

# %%
coeficientes_quadraticos = np.polyfit(df['Temp_AHT20_C'],df['Umid_AHT20_pct'],2) #treina com base na função quadratica
modelo_quadratico = np.poly1d(coeficientes_quadraticos) # calcula os coeficientes do modelo
modelo_quadratico
# Out:
# poly1d([-7.37127879e-02, -6.18756256e-01,  1.12499442e+02])

# %%
y_pred = modelo_quadratico(df['Temp_AHT20_C'])
y_pred #Valores da regressão (valores previsto de umidade) com base nas temperaturas do sensor
# Out:
# array([59.87375666, 59.99331323, 59.99331323, ..., 55.48135294,
#        55.43987907, 55.35688709])

# %%
# Acessa os coeficientes (c) do objeto poly1d
a = modelo_quadratico.coef[0]
b = modelo_quadratico.coef[1]
c = modelo_quadratico.coef[2]

# Cria um print formatado para mostrar a equação (y = ax^2 + bx + c)
print(f"Equação de Regressão Quadrática:")
print(f"Umid_AHT20_pct = ({a:.4f}) * Temp_AHT20_C^2 + ({b:.4f}) * Temp_AHT20_C + ({c:.4f})")
# Out:
# Equação de Regressão Quadrática:
# Umid_AHT20_pct = (-0.0737) * Temp_AHT20_C^2 + (-0.6188) * Temp_AHT20_C + (112.4994)

# %%
plt.scatter(df['Temp_AHT20_C'],df['Umid_AHT20_pct'])
plt.plot(df['Temp_AHT20_C'],y_pred, color='red')

# %% [markdown]
# -  vemos o modelo quadrático bem parecido com o modelo linear

# %% [markdown]
# - Para achar o r^2 nesse caso:

# %%
# Fazer as predições com o modelo
y_pred = modelo_quadratico(df['Temp_AHT20_C']) #umidade que ele previu com base na temperatura
y_real = df['Umid_AHT20_pct'] #umidade real do dataset

ss_res = np.sum((y_real - y_pred) ** 2)  # Soma dos quadrados dos resíduos
ss_tot = np.sum((y_real - np.mean(y_real)) ** 2)  # Soma total dos quadrados
r2 = 1 - (ss_res / ss_tot)

print(f"R² = {r2:.4f}")
# Out:
# R² = 0.8411

# %% [markdown]
# -  vemos que para esse modelo a temperatura explica 84% dos dados de umidade, logo temos uma breve melhora se comparado com o modelo linear (83%)3

# %%
333333333333333333
# Out:
# 333333333333333333

# %% [markdown]
# ## 2.2.  Regressão Polinomial de 3° Grau
#
# ---------------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
coeficientes_cubico = np.polyfit(df['Temp_AHT20_C'],df['Umid_AHT20_pct'], 3) # definicao e trieno do modelo como 3° grau
modelo_cubico = np.poly1d(coeficientes_cubico) #calcula os coeficientes
modelo_cubico
# Out:
# poly1d([ 7.74598744e-02, -4.85126446e+00,  9.65287378e+01, -5.38868223e+02])

# %%
a, b, c, d = coeficientes_cubico #pega os valores de a,b,c e d com base na equação de 3°
print(f"Y = {a:.4f}X³ + {b:.4f}X² + {c:.4f}X + {d:.4f}") #plota no formato
# Out:
# Y = 0.0775X³ + -4.8513X² + 96.5287X + -538.8682

# %%
Umidade_prevista = modelo_cubico(df['Temp_AHT20_C']) #previsao de umidade com base nos dados de temperatura
Umidade_prevista
# Out:
# array([57.9940685 , 58.10978171, 58.10978171, ..., 54.47567633,
#        54.44992964, 54.39886385])

# %%
plt.scatter(df['Temp_AHT20_C'],df['Umid_AHT20_pct']) #plota os pontos reais
plt.plot(df['Temp_AHT20_C'], Umidade_prevista ,color='red') #plota a curva prevista

# %%
umidade_prevista = modelo_cubico(df['Temp_AHT20_C']) #previsao de umidade com base nos dados de temperatura
umidade_real = df['Umid_AHT20_pct'] #pega os dados reais

ss_res = np.sum((umidade_real - umidade_prevista)**2) #soma dos quadrados dos resíduos
ss_tot = np.sum((umidade_real - np.mean(umidade_real))**2) #soma dos quadrados total

r2_cubico = 1 - (ss_res/ss_tot)
r2_cubico
# Out:
# np.float64(0.8565039096569586)

# %% [markdown]
# - Vemos novamente uma boa melhoria com a aplicação da regressão de 3° grau.

# %% [markdown]
# ## 2.3. Exercicio :  Regressão polinomial do 5° grau
#
# ------------

# %%
coeficientes_exercicio = np.polyfit(df['Temp_AHT20_C'],df['Umid_AHT20_pct'],5 )
modelo_exercicio = np.poly1d(coeficientes_exercicio) #calcula os coeficientes
modelo_exercicio
# Out:
# poly1d([-6.13802050e-03,  6.17696454e-01, -2.45980968e+01,  4.84228992e+02,
#        -4.71301923e+03,  1.82343620e+04])

# %%
a, b, c, d,e,f = coeficientes_exercicio #pega os valores de a,b,c e d com base na equação de 3°
print(f"Y = {a:.4f}X5 + {b:.4f}X4 + {c:.4f}X3 + {d:.4f}X2 + {e:.4f}X1 +  {f:.4f} ") #plota no formato
# Out:
# Y = -0.0061X5 + 0.6177X4 + -24.5981X3 + 484.2290X2 + -4713.0192X1 +  18234.3620

# %%
Umidade_prevista = modelo_exercicio(df['Temp_AHT20_C']) #previsao de umidade com base nos dados de temperatura
Umidade_prevista
# Out:
# array([57.71251599, 57.77904035, 57.77904035, ..., 55.93124307,
#        55.91558303, 55.8839713 ])

# %%
plt.scatter(df['Temp_AHT20_C'],df['Umid_AHT20_pct']) #plota os pontos reais
plt.plot(df['Temp_AHT20_C'], Umidade_prevista ,color='red') #plota a curva prevista

# %%
umidade_prevista = modelo_exercicio(df['Temp_AHT20_C']) #previsao de umidade com base nos dados de temperatura
umidade_real = df['Umid_AHT20_pct'] #pega os dados reais

ss_res = np.sum((umidade_real - umidade_prevista)**2) #soma dos quadrados dos resíduos
ss_tot = np.sum((umidade_real - np.mean(umidade_real))**2) #soma dos quadrados total

r2_cubico = 1 - (ss_res/ss_tot)
r2_cubico
# Out:
# np.float64(0.8640002474052745)

# %% [markdown]
# - leve melhora no r^2

# %% [markdown]
# # 3. Regressão logarítmica.
# ----------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Umid_AHT20_pct = β₀ + β₁·ln(Temp_AHT20_C) + ε

# %% [markdown]
# - Temperatura sendo variavel independente e temperatura sendo dependente

# %%
modelo_log = smf.ols(formula = 'Umid_AHT20_pct ~ np.log(Temp_AHT20_C)', data = df).fit()
print(modelo_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Umid_AHT20_pct   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                 2.504e+05
# Date:                Sat, 27 Sep 2025   Prob (F-statistic):               0.00
# Time:                        19:21:20   Log-Likelihood:            -1.5091e+05
# No. Observations:               51105   AIC:                         3.018e+05
# Df Residuals:                   51103   BIC:                         3.018e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              292.0038      0.444    657.222      0.000     291.133     292.875
# np.log(Temp_AHT20_C)   -74.3261      0.149   -500.356      0.000     -74.617     -74.035
# ==============================================================================
# Omnibus:                      949.346   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              803.951
# Skew:                          -0.244   Prob(JB):                    2.66e-175
# Kurtosis:                       2.626   Cond. No.                         72.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
modelo_log.params
# Out:
# Intercept               292.003776
# np.log(Temp_AHT20_C)    -74.326074
# dtype: float64

# %%
# Extrair os coeficientes
intercepto = modelo_log.params[0]
coef_log = modelo_log.params[1]
print(f"Umidade = {intercepto:.2f} + {coef_log:.2f} × ln(Temperatura)")

print()
print(f"Onde:")
print(f"  β₀ (intercepto) = {intercepto:.2f}")
print(f"  β₁ (coef. logarítmico) = {coef_log:.2f}")
print(f"  R² = {modelo_log.rsquared:.4f}")
# Out:
# Umidade = 292.00 + -74.33 × ln(Temperatura)
#
# Onde:
#   β₀ (intercepto) = 292.00
#   β₁ (coef. logarítmico) = -74.33
#   R² = 0.8305
# /tmp/ipython-input-3171710216.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercepto = modelo_log.params[0]
# /tmp/ipython-input-3171710216.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coef_log = modelo_log.params[1]

# %%
def funcao_logaritmica(x,a,b):
  return a+b*np.log(x)

# %%
Umidade_prevista_3 = funcao_logaritmica(df['Temp_AHT20_C'], modelo_log.params[0], modelo_log.params[1]) #preve os dados com base na função logritimica
# a função logaritmica recebe os parametros de icept e e coeficiente logaritimico
print(Umidade_prevista)
# Out:
# 0        59.441122
# 1        59.538770
# 2        59.538770
# 3        59.441122
# 4        59.506206
#            ...
# 51100    55.760548
# 51101    55.791510
# 51102    56.008612
# 51103    55.977558
# 51104    55.915491
# Length: 51105, dtype: float64
# /tmp/ipython-input-3792662695.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Umidade_prevista_3 = funcao_logaritmica(df['Temp_AHT20_C'], modelo_log.params[0], modelo_log.params[1])

# %%
plt.scatter(df['Temp_AHT20_C'],df['Umid_AHT20_pct']) #plota os pontos reais
plt.plot(df['Temp_AHT20_C'], Umidade_prevista_3 ,color='red') #plota a curva prevista

# %% [markdown]
# # 4. Regressão Exponencial
#
# -----------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
modelo_exp = smf.ols('np.log(Umid_AHT20_pct) ~ Temp_AHT20_C', data=df).fit() #o controrio da logaritmica

# %%
print(modelo_exp.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(Umid_AHT20_pct)   R-squared:                       0.832
# Model:                                OLS   Adj. R-squared:                  0.832
# Method:                     Least Squares   F-statistic:                 2.523e+05
# Date:                    Sat, 27 Sep 2025   Prob (F-statistic):               0.00
# Time:                            19:34:48   Log-Likelihood:                 63144.
# No. Observations:                   51105   AIC:                        -1.263e+05
# Df Residuals:                       51103   BIC:                        -1.263e+05
# Df Model:                               1
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        5.3453      0.002   2391.499      0.000       5.341       5.350
# Temp_AHT20_C    -0.0555      0.000   -502.340      0.000      -0.056      -0.055
# ==============================================================================
# Omnibus:                      541.049   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              517.703
# Skew:                          -0.218   Prob(JB):                    3.82e-113
# Kurtosis:                       2.768   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - quase mesmo resultado de r^2 se comparado ao do logaritimico

# %%
intercepto = modelo_exp.params[0]
coef = modelo_exp.params[1]

# 4. IMPRIMIR A FUNÇÃO EXPONENCIAL
print("\n" + "="*60)
print("FUNÇÃO EXPONENCIAL AJUSTADA:")
print("="*60)
print(f"ln(Umidade) = {intercepto:.4f} + {coef:.4f} × Temperatura")
print(f"\nForma exponencial:")
print(f"Umidade = {np.exp(intercepto):.2f} × e^({coef:.4f} × Temperatura)")
# Out:
# ============================================================
# FUNÇÃO EXPONENCIAL AJUSTADA:
# ============================================================
# ln(Umidade) = 5.3453 + -0.0555 × Temperatura
#
# Forma exponencial:
# Umidade = 209.62 × e^(-0.0555 × Temperatura)
# /tmp/ipython-input-537828677.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercepto = modelo_exp.params[0]
# /tmp/ipython-input-537828677.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coef = modelo_exp.params[1]

# %%
def funcao_exponencial(x,a,b):
  return np.exp(a+b*x)

# %%
previsao_umidade_exp = funcao_exponencial(df['Temp_AHT20_C'], modelo_exp.params[0], modelo_exp.params[1])
previsao_umidade_exp
# Out:
# /tmp/ipython-input-3566199791.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   previsao_umidade_exp = funcao_exponencial(df['Temp_AHT20_C'], modelo_exp.params[0], modelo_exp.params[1])
# 0        58.978548
# 1        59.076826
# 2        59.076826
# 3        58.978548
# 4        59.044048
#            ...
# 51100    55.301258
# 51101    55.331957
# 51102    55.547334
# 51103    55.516515
# 51104    55.454927
# Name: Temp_AHT20_C, Length: 51105, dtype: float64

# %%
plt.scatter(df['Temp_AHT20_C'],df['Umid_AHT20_pct']) #plota os pontos reais
plt.plot(df['Temp_AHT20_C'], previsao_umidade_exp ,color='red') #plota a curva prevista

# %% [markdown]
# exponencial e logarítmica ( R
# 2
#  ≈0.830 ) não capturaram adequadamente a curvatura dos dados de Umidade vs. Temperatura, indicando que a relação entre as variáveis é melhor modelada por uma curva cúbica, que é mais flexível para capturar mudanças de concavidade nos extremos da faixa de temperatura. Assim, a regressão polinomial cúbica forneceu a melhor descrição estatística para a relação observada.
